# %%
import random

# %%
import pandas as pd

file_path = 'dataset/symptoms_diagnosis.csv'

df = pd.read_csv(file_path)

print(df.head())
# Out:
#        label                                               text
# 0  Psoriasis  I have been experiencing a skin rash on my arm...
# 1  Psoriasis  My skin has been peeling, especially on my kne...
# 2  Psoriasis  I have been experiencing joint pain in my fing...
# 3  Psoriasis  There is a silver like dusting on my skin, esp...
# 4  Psoriasis  My nails have small dents or pits in them, and...

# %%
csv_data = []
for _, row in df.iterrows():
    diagnosis = row['label']
    symptoms = row['text']
    prompt = f"You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: '{symptoms}'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with {diagnosis}."
    csv_data.append({"text": prompt})
random.shuffle(csv_data)
csv_data[:10]
# Out:
# [{'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'The rash on my legs is spreading and becoming more severe. It has become very difficult for me to run.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Varicose Veins."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing dizziness, sore throat, cough, vomiting.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Arthritis."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing night sweats, dizziness, sore throat, diarrhea, skin rash, rapid heartbeat.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with HIV/AIDS."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have increased thirst and frequent urination. I often have a dry mouth and throat. Recently I have been having increased hunger and appetite'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with diabetes."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing memory loss, speech difficulty, swelling.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Ulcer."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing loss of appetite, muscle pain, swelling.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Osteoporosis."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing swelling, increased urination, weight loss, rapid heartbeat, dry skin, nausea.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Rubella."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing vomiting, chest pain, vision changes, joint pain, dizziness.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Pneumonia."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing fatigue, vision changes, difficulty breathing, chest pain, fever.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Arthritis."},
#  {'text': "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I've been exhausted and experiencing nausea and itching. In addition, I've lost weight and have a temperature. My urine is dark, and my skin has turned yellow. Additionally, I've been having stomach pain.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Jaundice."}]

# %%
# calculate split indices
total_records = len(csv_data)
train_split = int(total_records * 2 / 3)
test_split = int(total_records * 1 / 6)
print(train_split, test_split)
# Out:
# 3333 833

# %%
# split the data
train_data = csv_data[:train_split]
test_data = csv_data[train_split:train_split + test_split]
valid_data = csv_data[train_split + test_split:]

# %%
import json
with open('train.jsonl', 'w') as train_file:
    for entry in train_data:
        train_file.write(json.dumps(entry) + '\n')

with open('test.jsonl', 'w') as test_file:
    for entry in test_data:
        test_file.write(json.dumps(entry) + '\n')

with open('valid.jsonl', 'w') as valid_file:
    for entry in valid_data:
        valid_file.write(json.dumps(entry) + '\n')

# %%
with open('data/train.jsonl', 'r') as train_file:
    for _ in range(3):
        print(train_file.readline())
    train_file.close()
print('------------------------------------')
with open('data/test.jsonl', 'r') as test_file:
    for _ in range(3):
        print(test_file.readline())
    test_file.close()
print('------------------------------------')
with open('data/valid.jsonl', 'r') as valid_file:
    for _ in range(3):
        print(valid_file.readline())
    valid_file.close()
# Out:
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'The rash on my legs is spreading and becoming more severe. It has become very difficult for me to run.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Varicose Veins."}
#
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing dizziness, sore throat, cough, vomiting.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Arthritis."}
#
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing night sweats, dizziness, sore throat, diarrhea, skin rash, rapid heartbeat.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with HIV/AIDS."}
#
# ------------------------------------
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing skin rash, weight loss, joint pain, dizziness.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Tonsillitis."}
#
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing dry skin, dizziness, difficulty walking, abdominal pain, fever, fatigue.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Mumps."}
#
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I've been drinking more water and urinating more frequently. My throat and mouth frequently feel dry. Recently, both my hunger and appetite have grown.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with diabetes."}
#
# ------------------------------------
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have little red spots all over my body that I don't understand. It worries me. I have lost my appetite and every night, I am exhausted and have a severe headache.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Chicken pox."}
#
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing skin rash, fatigue, difficulty walking, hair loss.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Rubella."}
#
# {"text": "You are a medical diagnosis expert. You will give answer to patient's question based on the symptoms they have. Symptoms: 'I have been experiencing cough, vomiting, memory loss, tremors, skin rash, shortness of breath.'. Question: 'What is the diagnosis I have?'. Response: You may be diagnosed with Tonsillitis."}

# %%
# !huggingface-cli download mlx-community/Ministral-8B-Instruct-2410-4bit
# Out:
# python(32065) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Fetching 9 files:   0%|                                   | 0/9 [00:00<?, ?it/s]Downloading '.gitattributes' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/0d4cb185280917cac60ef7195f2a6250b2b90d83.incomplete'
# Downloading 'README.md' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/6e730e859b612a76f38219ff8a92aaa16cdbc45c.incomplete'
# Downloading 'config.json' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/9d1fb73368b5fc9a0bc89348a69f4db7b42b0234.incomplete'
# Downloading 'special_tokens_map.json' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/d91fcde70f007f758e57bf674b33e7c820bdb514.incomplete'
# Downloading 'model.safetensors.index.json' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/cc40d116d33ed08b69f9987a67b8952b895e52b1.incomplete'
#
# special_tokens_map.json: 100%|█████████████████| 276/276 [00:00<00:00, 2.70MB/s]
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/d91fcde70f007f758e57bf674b33e7c820bdb514
#
# README.md: 100%|███████████████████████████| 14.3k/14.3k [00:00<00:00, 73.4MB/s]
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/6e730e859b612a76f38219ff8a92aaa16cdbc45c
#
# .gitattributes: 100%|██████████████████████| 1.62k/1.62k [00:00<00:00, 15.6MB/s]
#
# config.json: 100%|█████████████████████████████| 819/819 [00:00<00:00, 13.0MB/s]
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/0d4cb185280917cac60ef7195f2a6250b2b90d83
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/9d1fb73368b5fc9a0bc89348a69f4db7b42b0234
# Fetching 9 files:  11%|███                        | 1/9 [00:00<00:01,  5.00it/s]Downloading 'tekken.json' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/eccd1665d2e477697c33cb7f0daa6f6dfefc57a0a6bceb66d4be52952f827516.incomplete'
# Downloading 'tokenizer.json' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/bca6a29c306733e3cdcb4826f64a49b1fcebf91fe9aeb883d05dbfec3dc0b259.incomplete'
# Downloading 'model.safetensors' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/7049798d4a6002e3d8df810b9a31c4fe4846d35a88c7b947abe6ce5222498b16.incomplete'
#
# model.safetensors.index.json:   0%|                 | 0.00/58.9k [00:00<?, ?B/s]Downloading 'tokenizer_config.json' to '/Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/0513db177c4ef00b187c6006cbc0818319426c64.incomplete'
# model.safetensors.index.json: 100%|████████| 58.9k/58.9k [00:00<00:00, 2.20MB/s]
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/cc40d116d33ed08b69f9987a67b8952b895e52b1
#
# tokenizer_config.json: 100%|█████████████████| 181k/181k [00:00<00:00, 5.41MB/s]
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/0513db177c4ef00b187c6006cbc0818319426c64
#
# tekken.json:   0%|                                  | 0.00/14.8M [00:00<?, ?B/s]
#
# model.safetensors:   0%|                            | 0.00/4.51G [00:00<?, ?B/s]
#
#
# tokenizer.json:   0%|                               | 0.00/17.1M [00:00<?, ?B/s]
# tekken.json:  71%|█████████████████▋       | 10.5M/14.8M [00:00<00:00, 32.9MB/s]
# tekken.json: 100%|█████████████████████████| 14.8M/14.8M [00:00<00:00, 34.1MB/s]
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/eccd1665d2e477697c33cb7f0daa6f6dfefc57a0a6bceb66d4be52952f827516
#
#
# model.safetensors:   0%|                   | 10.5M/4.51G [00:00<02:49, 26.6MB/s]
#
# model.safetensors:   0%|                   | 21.0M/4.51G [00:00<01:55, 38.8MB/s]
#
# model.safetensors:   1%|▏                  | 31.5M/4.51G [00:00<01:52, 40.0MB/s]
#
#
# tokenizer.json:  61%|█████████████▌        | 10.5M/17.1M [00:00<00:00, 12.0MB/s]
#
# model.safetensors:   1%|▏                  | 41.9M/4.51G [00:01<01:49, 41.0MB/s]
#
#
# tokenizer.json: 100%|██████████████████████| 17.1M/17.1M [00:01<00:00, 14.0MB/s]
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/bca6a29c306733e3cdcb4826f64a49b1fcebf91fe9aeb883d05dbfec3dc0b259
#
#
# model.safetensors:   1%|▏                  | 52.4M/4.51G [00:01<01:47, 41.5MB/s]
#
# model.safetensors:   1%|▎                  | 62.9M/4.51G [00:01<01:46, 42.0MB/s]
#
# model.safetensors:   2%|▎                  | 73.4M/4.51G [00:01<01:45, 42.0MB/s]
#
# model.safetensors:   2%|▎                  | 83.9M/4.51G [00:02<01:44, 42.3MB/s]
#
# model.safetensors:   2%|▍                  | 94.4M/4.51G [00:02<01:44, 42.1MB/s]
#
# model.safetensors:   2%|▍                   | 105M/4.51G [00:02<01:43, 42.4MB/s]
#
# model.safetensors:   3%|▌                   | 115M/4.51G [00:02<01:43, 42.6MB/s]
#
# model.safetensors:   3%|▌                   | 126M/4.51G [00:03<01:43, 42.6MB/s]
#
# model.safetensors:   3%|▌                   | 136M/4.51G [00:03<01:43, 42.2MB/s]
#
# model.safetensors:   3%|▋                   | 147M/4.51G [00:03<01:43, 42.2MB/s]
#
# model.safetensors:   3%|▋                   | 157M/4.51G [00:03<01:43, 42.2MB/s]
#
# model.safetensors:   4%|▋                   | 168M/4.51G [00:04<01:42, 42.5MB/s]
#
# model.safetensors:   4%|▊                   | 178M/4.51G [00:04<01:41, 42.5MB/s]
#
# model.safetensors:   4%|▊                   | 189M/4.51G [00:04<01:42, 42.4MB/s]
#
# model.safetensors:   4%|▉                   | 199M/4.51G [00:04<01:41, 42.3MB/s]
#
# model.safetensors:   5%|▉                   | 210M/4.51G [00:05<01:41, 42.4MB/s]
#
# model.safetensors:   5%|▉                   | 220M/4.51G [00:05<01:40, 42.6MB/s]
#
# model.safetensors:   5%|█                   | 231M/4.51G [00:05<01:40, 42.5MB/s]
#
# model.safetensors:   5%|█                   | 241M/4.51G [00:05<01:40, 42.4MB/s]
#
# model.safetensors:   6%|█                   | 252M/4.51G [00:06<01:40, 42.4MB/s]
#
# model.safetensors:   6%|█▏                  | 262M/4.51G [00:06<01:40, 42.3MB/s]
#
# model.safetensors:   6%|█▏                  | 273M/4.51G [00:06<01:39, 42.6MB/s]
#
# model.safetensors:   6%|█▎                  | 283M/4.51G [00:06<01:39, 42.6MB/s]
#
# model.safetensors:   7%|█▎                  | 294M/4.51G [00:07<01:40, 42.1MB/s]
#
# model.safetensors:   7%|█▎                  | 304M/4.51G [00:07<01:39, 42.3MB/s]
#
# model.safetensors:   7%|█▍                  | 315M/4.51G [00:07<01:39, 42.1MB/s]
#
# model.safetensors:   7%|█▍                  | 325M/4.51G [00:07<01:39, 42.2MB/s]
#
# model.safetensors:   7%|█▍                  | 336M/4.51G [00:08<01:39, 42.2MB/s]
#
# model.safetensors:   8%|█▌                  | 346M/4.51G [00:08<01:38, 42.3MB/s]
#
# model.safetensors:   8%|█▌                  | 357M/4.51G [00:08<01:38, 42.4MB/s]
#
# model.safetensors:   8%|█▋                  | 367M/4.51G [00:08<01:38, 42.3MB/s]
#
# model.safetensors:   8%|█▋                  | 377M/4.51G [00:08<01:37, 42.3MB/s]
#
# model.safetensors:   9%|█▋                  | 388M/4.51G [00:09<01:37, 42.3MB/s]
#
# model.safetensors:   9%|█▊                  | 398M/4.51G [00:09<01:37, 42.3MB/s]
#
# model.safetensors:   9%|█▊                  | 409M/4.51G [00:09<01:36, 42.4MB/s]
#
# model.safetensors:   9%|█▊                  | 419M/4.51G [00:09<01:36, 42.4MB/s]
#
# model.safetensors:  10%|█▉                  | 430M/4.51G [00:10<01:36, 42.2MB/s]
#
# model.safetensors:  10%|█▉                  | 440M/4.51G [00:10<01:36, 42.3MB/s]
#
# model.safetensors:  10%|█▉                  | 451M/4.51G [00:10<01:36, 42.3MB/s]
#
# model.safetensors:  10%|██                  | 461M/4.51G [00:10<01:35, 42.3MB/s]
#
# model.safetensors:  10%|██                  | 472M/4.51G [00:11<01:35, 42.4MB/s]
#
# model.safetensors:  11%|██▏                 | 482M/4.51G [00:11<01:35, 42.0MB/s]
#
# model.safetensors:  11%|██▏                 | 493M/4.51G [00:11<01:35, 42.0MB/s]
#
# model.safetensors:  11%|██▏                 | 503M/4.51G [00:11<01:34, 42.2MB/s]
#
# model.safetensors:  11%|██▎                 | 514M/4.51G [00:12<01:34, 42.3MB/s]
#
# model.safetensors:  12%|██▎                 | 524M/4.51G [00:12<01:34, 42.1MB/s]
#
# model.safetensors:  12%|██▎                 | 535M/4.51G [00:12<01:34, 42.2MB/s]
#
# model.safetensors:  12%|██▍                 | 545M/4.51G [00:12<01:34, 42.0MB/s]
#
# model.safetensors:  12%|██▍                 | 556M/4.51G [00:13<01:34, 42.1MB/s]
#
# model.safetensors:  13%|██▌                 | 566M/4.51G [00:13<01:33, 42.1MB/s]
#
# model.safetensors:  13%|██▌                 | 577M/4.51G [00:13<01:32, 42.4MB/s]
#
# model.safetensors:  13%|██▌                 | 587M/4.51G [00:13<01:33, 42.1MB/s]
#
# model.safetensors:  13%|██▋                 | 598M/4.51G [00:14<01:32, 42.2MB/s]
#
# model.safetensors:  13%|██▋                 | 608M/4.51G [00:14<01:32, 42.2MB/s]
#
# model.safetensors:  14%|██▋                 | 619M/4.51G [00:14<01:31, 42.4MB/s]
#
# model.safetensors:  14%|██▊                 | 629M/4.51G [00:14<01:32, 41.8MB/s]
#
# model.safetensors:  14%|██▊                 | 640M/4.51G [00:15<01:31, 42.3MB/s]
#
# model.safetensors:  14%|██▉                 | 650M/4.51G [00:15<01:31, 42.3MB/s]
#
# model.safetensors:  15%|██▉                 | 661M/4.51G [00:15<01:31, 42.2MB/s]
#
# model.safetensors:  15%|██▉                 | 671M/4.51G [00:15<01:30, 42.6MB/s]
#
# model.safetensors:  15%|███                 | 682M/4.51G [00:16<01:29, 42.8MB/s]
#
# model.safetensors:  15%|███                 | 692M/4.51G [00:16<01:29, 42.6MB/s]
#
# model.safetensors:  16%|███                 | 703M/4.51G [00:16<01:29, 42.5MB/s]
#
# model.safetensors:  16%|███▏                | 713M/4.51G [00:16<01:29, 42.6MB/s]
#
# model.safetensors:  16%|███▏                | 724M/4.51G [00:17<01:28, 42.8MB/s]
#
# model.safetensors:  16%|███▎                | 734M/4.51G [00:17<01:28, 42.8MB/s]
#
# model.safetensors:  17%|███▎                | 744M/4.51G [00:17<01:28, 42.8MB/s]
#
# model.safetensors:  17%|███▎                | 755M/4.51G [00:17<01:27, 42.8MB/s]
#
# model.safetensors:  17%|███▍                | 765M/4.51G [00:18<01:27, 42.7MB/s]
#
# model.safetensors:  17%|███▍                | 776M/4.51G [00:18<01:27, 42.7MB/s]
#
# model.safetensors:  17%|███▍                | 786M/4.51G [00:18<01:27, 42.6MB/s]
#
# model.safetensors:  18%|███▌                | 797M/4.51G [00:18<01:27, 42.5MB/s]
#
# model.safetensors:  18%|███▌                | 807M/4.51G [00:19<01:26, 42.6MB/s]
#
# model.safetensors:  18%|███▋                | 818M/4.51G [00:19<01:40, 36.6MB/s]
#
# model.safetensors:  18%|███▋                | 828M/4.51G [00:19<01:30, 40.8MB/s]
#
# model.safetensors:  19%|███▋                | 839M/4.51G [00:19<01:29, 41.1MB/s]
#
# model.safetensors:  19%|███▊                | 849M/4.51G [00:20<01:28, 41.4MB/s]
#
# model.safetensors:  19%|███▊                | 860M/4.51G [00:20<01:27, 41.7MB/s]
#
# model.safetensors:  19%|███▊                | 870M/4.51G [00:20<01:26, 42.0MB/s]
#
# model.safetensors:  20%|███▉                | 881M/4.51G [00:20<01:26, 42.1MB/s]
#
# model.safetensors:  20%|███▉                | 891M/4.51G [00:21<01:26, 41.7MB/s]
#
# model.safetensors:  20%|███▉                | 902M/4.51G [00:21<01:26, 41.5MB/s]
#
# model.safetensors:  20%|████                | 912M/4.51G [00:21<01:26, 41.6MB/s]
#
# model.safetensors:  20%|████                | 923M/4.51G [00:21<01:25, 41.9MB/s]
#
# model.safetensors:  21%|████▏               | 933M/4.51G [00:22<01:25, 41.8MB/s]
#
# model.safetensors:  21%|████▏               | 944M/4.51G [00:22<01:25, 41.9MB/s]
#
# model.safetensors:  21%|████▏               | 954M/4.51G [00:22<01:24, 42.3MB/s]
#
# model.safetensors:  21%|████▎               | 965M/4.51G [00:22<01:23, 42.3MB/s]
#
# model.safetensors:  22%|████▎               | 975M/4.51G [00:23<01:23, 42.2MB/s]
#
# model.safetensors:  22%|████▎               | 986M/4.51G [00:23<01:23, 42.3MB/s]
#
# model.safetensors:  22%|████▍               | 996M/4.51G [00:23<01:23, 42.2MB/s]
#
# model.safetensors:  22%|████▏              | 1.01G/4.51G [00:23<01:22, 42.3MB/s]
#
# model.safetensors:  23%|████▎              | 1.02G/4.51G [00:24<01:22, 42.3MB/s]
#
# model.safetensors:  23%|████▎              | 1.03G/4.51G [00:24<01:22, 42.4MB/s]
#
# model.safetensors:  23%|████▎              | 1.04G/4.51G [00:24<01:21, 42.5MB/s]
#
# model.safetensors:  23%|████▍              | 1.05G/4.51G [00:24<01:22, 42.1MB/s]
#
# model.safetensors:  23%|████▍              | 1.06G/4.51G [00:25<01:21, 42.3MB/s]
#
# model.safetensors:  24%|████▌              | 1.07G/4.51G [00:25<01:21, 42.0MB/s]
#
# model.safetensors:  24%|████▌              | 1.08G/4.51G [00:25<01:21, 42.0MB/s]
#
# model.safetensors:  24%|████▌              | 1.09G/4.51G [00:25<01:21, 42.2MB/s]
#
# model.safetensors:  24%|████▋              | 1.10G/4.51G [00:26<01:20, 42.2MB/s]
#
# model.safetensors:  25%|████▋              | 1.11G/4.51G [00:26<01:20, 42.1MB/s]
#
# model.safetensors:  25%|████▋              | 1.12G/4.51G [00:26<01:20, 42.0MB/s]
#
# model.safetensors:  25%|████▊              | 1.13G/4.51G [00:26<01:20, 41.9MB/s]
#
# model.safetensors:  25%|████▊              | 1.14G/4.51G [00:27<01:20, 42.0MB/s]
#
# model.safetensors:  26%|████▊              | 1.15G/4.51G [00:27<01:19, 42.3MB/s]
#
# model.safetensors:  26%|████▉              | 1.16G/4.51G [00:27<01:19, 42.2MB/s]
#
# model.safetensors:  26%|████▉              | 1.17G/4.51G [00:27<01:19, 42.1MB/s]
#
# model.safetensors:  26%|████▉              | 1.18G/4.51G [00:28<01:18, 42.5MB/s]
#
# model.safetensors:  26%|█████              | 1.20G/4.51G [00:28<01:17, 42.7MB/s]
#
# model.safetensors:  27%|█████              | 1.21G/4.51G [00:28<01:17, 42.6MB/s]
#
# model.safetensors:  27%|█████              | 1.22G/4.51G [00:28<01:18, 42.1MB/s]
#
# model.safetensors:  27%|█████▏             | 1.23G/4.51G [00:29<01:18, 41.7MB/s]
#
# model.safetensors:  27%|█████▏             | 1.24G/4.51G [00:29<01:18, 41.7MB/s]
#
# model.safetensors:  28%|█████▎             | 1.25G/4.51G [00:29<01:18, 41.8MB/s]
#
# model.safetensors:  28%|█████▎             | 1.26G/4.51G [00:30<01:30, 36.1MB/s]
#
# model.safetensors:  28%|█████▎             | 1.27G/4.51G [00:30<01:14, 43.6MB/s]
#
# model.safetensors:  28%|█████▍             | 1.28G/4.51G [00:30<01:14, 43.6MB/s]
#
# model.safetensors:  29%|█████▍             | 1.29G/4.51G [00:30<01:14, 43.1MB/s]
#
# model.safetensors:  29%|█████▍             | 1.30G/4.51G [00:30<01:15, 42.7MB/s]
#
# model.safetensors:  29%|█████▌             | 1.31G/4.51G [00:31<01:15, 42.2MB/s]
#
# model.safetensors:  29%|█████▌             | 1.32G/4.51G [00:31<01:15, 42.1MB/s]
#
# model.safetensors:  30%|█████▌             | 1.33G/4.51G [00:31<01:15, 42.4MB/s]
#
# model.safetensors:  30%|█████▋             | 1.34G/4.51G [00:31<01:14, 42.6MB/s]
#
# model.safetensors:  30%|█████▋             | 1.35G/4.51G [00:32<01:14, 42.5MB/s]
#
# model.safetensors:  30%|█████▋             | 1.36G/4.51G [00:32<01:14, 42.4MB/s]
#
# model.safetensors:  30%|█████▊             | 1.37G/4.51G [00:32<01:14, 42.2MB/s]
#
# model.safetensors:  31%|█████▊             | 1.38G/4.51G [00:32<01:14, 41.8MB/s]
#
# model.safetensors:  31%|█████▊             | 1.39G/4.51G [00:33<01:14, 42.1MB/s]
#
# model.safetensors:  31%|█████▉             | 1.41G/4.51G [00:33<01:14, 41.9MB/s]
#
# model.safetensors:  31%|█████▉             | 1.42G/4.51G [00:33<01:13, 42.1MB/s]
#
# model.safetensors:  32%|██████             | 1.43G/4.51G [00:33<01:13, 42.1MB/s]
#
# model.safetensors:  32%|██████             | 1.44G/4.51G [00:34<01:13, 42.1MB/s]
#
# model.safetensors:  32%|██████             | 1.45G/4.51G [00:34<01:12, 42.2MB/s]
#
# model.safetensors:  32%|██████▏            | 1.46G/4.51G [00:34<01:12, 42.2MB/s]
#
# model.safetensors:  33%|██████▏            | 1.47G/4.51G [00:34<01:11, 42.3MB/s]
#
# model.safetensors:  33%|██████▏            | 1.48G/4.51G [00:35<01:11, 42.3MB/s]
#
# model.safetensors:  33%|██████▎            | 1.49G/4.51G [00:35<01:11, 42.3MB/s]
#
# model.safetensors:  33%|██████▎            | 1.50G/4.51G [00:35<01:12, 41.8MB/s]
#
# model.safetensors:  33%|██████▎            | 1.51G/4.51G [00:35<01:12, 41.4MB/s]
#
# model.safetensors:  34%|██████▍            | 1.52G/4.51G [00:36<01:12, 41.3MB/s]
#
# model.safetensors:  34%|██████▍            | 1.53G/4.51G [00:36<01:11, 41.6MB/s]
#
# model.safetensors:  34%|██████▍            | 1.54G/4.51G [00:36<01:11, 41.6MB/s]
#
# model.safetensors:  34%|██████▌            | 1.55G/4.51G [00:36<01:10, 42.2MB/s]
#
# model.safetensors:  35%|██████▌            | 1.56G/4.51G [00:37<01:09, 42.4MB/s]
#
# model.safetensors:  35%|██████▌            | 1.57G/4.51G [00:37<01:09, 42.5MB/s]
#
# model.safetensors:  35%|██████▋            | 1.58G/4.51G [00:37<01:09, 42.4MB/s]
#
# model.safetensors:  35%|██████▋            | 1.59G/4.51G [00:37<01:09, 42.2MB/s]
#
# model.safetensors:  36%|██████▊            | 1.60G/4.51G [00:38<01:08, 42.2MB/s]
#
# model.safetensors:  36%|██████▊            | 1.61G/4.51G [00:38<01:08, 42.4MB/s]
#
# model.safetensors:  36%|██████▊            | 1.63G/4.51G [00:38<01:08, 42.2MB/s]
#
# model.safetensors:  36%|██████▉            | 1.64G/4.51G [00:38<01:08, 41.9MB/s]
#
# model.safetensors:  36%|██████▉            | 1.65G/4.51G [00:39<01:09, 41.4MB/s]
#
# model.safetensors:  37%|██████▉            | 1.66G/4.51G [00:39<01:07, 42.2MB/s]
#
# model.safetensors:  37%|███████            | 1.67G/4.51G [00:39<01:07, 42.0MB/s]
#
# model.safetensors:  37%|███████            | 1.68G/4.51G [00:39<01:07, 41.9MB/s]
#
# model.safetensors:  37%|███████            | 1.69G/4.51G [00:40<01:07, 41.8MB/s]
#
# model.safetensors:  38%|███████▏           | 1.70G/4.51G [00:40<01:06, 42.0MB/s]
#
# model.safetensors:  38%|███████▏           | 1.71G/4.51G [00:40<01:06, 42.2MB/s]
#
# model.safetensors:  38%|███████▏           | 1.72G/4.51G [00:40<01:06, 42.3MB/s]
#
# model.safetensors:  38%|███████▎           | 1.73G/4.51G [00:41<01:06, 42.1MB/s]
#
# model.safetensors:  39%|███████▎           | 1.74G/4.51G [00:41<01:04, 42.7MB/s]
#
# model.safetensors:  39%|███████▎           | 1.75G/4.51G [00:41<01:05, 42.4MB/s]
#
# model.safetensors:  39%|███████▍           | 1.76G/4.51G [00:41<01:04, 42.6MB/s]
#
# model.safetensors:  39%|███████▍           | 1.77G/4.51G [00:42<01:04, 42.5MB/s]
#
# model.safetensors:  40%|███████▌           | 1.78G/4.51G [00:42<01:04, 42.4MB/s]
#
# model.safetensors:  40%|███████▌           | 1.79G/4.51G [00:42<01:04, 42.3MB/s]
#
# model.safetensors:  40%|███████▌           | 1.80G/4.51G [00:42<01:04, 42.2MB/s]
#
# model.safetensors:  40%|███████▋           | 1.81G/4.51G [00:43<01:03, 42.3MB/s]
#
# model.safetensors:  40%|███████▋           | 1.82G/4.51G [00:43<01:03, 42.5MB/s]
#
# model.safetensors:  41%|███████▋           | 1.84G/4.51G [00:43<01:03, 42.4MB/s]
#
# model.safetensors:  41%|███████▊           | 1.85G/4.51G [00:43<01:03, 41.9MB/s]
#
# model.safetensors:  41%|███████▊           | 1.86G/4.51G [00:44<01:02, 42.3MB/s]
#
# model.safetensors:  41%|███████▊           | 1.87G/4.51G [00:44<01:02, 42.3MB/s]
#
# model.safetensors:  42%|███████▉           | 1.88G/4.51G [00:44<01:02, 42.1MB/s]
#
# model.safetensors:  42%|███████▉           | 1.89G/4.51G [00:44<01:02, 41.9MB/s]
#
# model.safetensors:  42%|███████▉           | 1.90G/4.51G [00:45<01:02, 41.7MB/s]
#
# model.safetensors:  42%|████████           | 1.91G/4.51G [00:45<01:02, 41.8MB/s]
#
# model.safetensors:  43%|████████           | 1.92G/4.51G [00:45<01:01, 42.0MB/s]
#
# model.safetensors:  43%|████████▏          | 1.93G/4.51G [00:46<01:16, 33.8MB/s]
#
# model.safetensors:  43%|████████▏          | 1.94G/4.51G [00:46<01:04, 39.9MB/s]
#
# model.safetensors:  43%|████████▏          | 1.95G/4.51G [00:46<00:55, 46.5MB/s]
#
# model.safetensors:  43%|████████▎          | 1.96G/4.51G [00:46<00:56, 45.0MB/s]
#
# model.safetensors:  44%|████████▎          | 1.97G/4.51G [00:46<00:58, 43.7MB/s]
#
# model.safetensors:  44%|████████▎          | 1.98G/4.51G [00:47<00:58, 43.6MB/s]
#
# model.safetensors:  44%|████████▍          | 1.99G/4.51G [00:47<00:58, 43.0MB/s]
#
# model.safetensors:  44%|████████▍          | 2.00G/4.51G [00:47<00:58, 42.9MB/s]
#
# model.safetensors:  45%|████████▍          | 2.01G/4.51G [00:47<00:58, 43.0MB/s]
#
# model.safetensors:  45%|████████▌          | 2.02G/4.51G [00:48<00:58, 42.8MB/s]
#
# model.safetensors:  45%|████████▌          | 2.03G/4.51G [00:48<00:58, 42.2MB/s]
#
# model.safetensors:  45%|████████▌          | 2.04G/4.51G [00:48<00:58, 42.5MB/s]
#
# model.safetensors:  46%|████████▋          | 2.06G/4.51G [00:48<00:57, 42.8MB/s]
#
# model.safetensors:  46%|████████▋          | 2.07G/4.51G [00:49<00:57, 42.4MB/s]
#
# model.safetensors:  46%|████████▋          | 2.08G/4.51G [00:49<00:57, 42.5MB/s]
#
# model.safetensors:  46%|████████▊          | 2.09G/4.51G [00:49<00:57, 42.1MB/s]
#
# model.safetensors:  46%|████████▊          | 2.10G/4.51G [00:49<00:57, 42.2MB/s]
#
# model.safetensors:  47%|████████▉          | 2.11G/4.51G [00:50<00:57, 42.1MB/s]
#
# model.safetensors:  47%|████████▉          | 2.12G/4.51G [00:50<00:56, 42.1MB/s]
#
# model.safetensors:  47%|████████▉          | 2.13G/4.51G [00:50<00:56, 42.2MB/s]
#
# model.safetensors:  47%|█████████          | 2.14G/4.51G [00:50<00:55, 42.5MB/s]
#
# model.safetensors:  48%|█████████          | 2.15G/4.51G [00:51<00:56, 42.2MB/s]
#
# model.safetensors:  48%|█████████          | 2.16G/4.51G [00:51<00:54, 43.5MB/s]
#
# model.safetensors:  48%|█████████▏         | 2.17G/4.51G [00:51<00:51, 45.2MB/s]
#
# model.safetensors:  48%|█████████▏         | 2.18G/4.51G [00:51<00:48, 47.9MB/s]
#
# model.safetensors:  49%|█████████▏         | 2.19G/4.51G [00:51<00:47, 48.5MB/s]
#
# model.safetensors:  49%|█████████▎         | 2.20G/4.51G [00:52<00:50, 45.9MB/s]
#
# model.safetensors:  49%|█████████▎         | 2.21G/4.51G [00:52<00:51, 44.8MB/s]
#
# model.safetensors:  49%|█████████▎         | 2.22G/4.51G [00:52<00:51, 44.0MB/s]
#
# model.safetensors:  50%|█████████▍         | 2.23G/4.51G [00:52<00:52, 43.5MB/s]
#
# model.safetensors:  50%|█████████▍         | 2.24G/4.51G [00:53<00:53, 42.1MB/s]
#
# model.safetensors:  50%|█████████▍         | 2.25G/4.51G [00:53<00:57, 39.1MB/s]
#
# model.safetensors:  50%|█████████▌         | 2.26G/4.51G [00:53<00:56, 39.6MB/s]
#
# model.safetensors:  50%|█████████▌         | 2.28G/4.51G [00:53<00:53, 41.7MB/s]
#
# model.safetensors:  51%|█████████▋         | 2.29G/4.51G [00:54<00:50, 44.3MB/s]
#
# model.safetensors:  51%|█████████▋         | 2.30G/4.51G [00:54<00:50, 43.8MB/s]
#
# model.safetensors:  51%|█████████▋         | 2.31G/4.51G [00:54<00:50, 43.4MB/s]
#
# model.safetensors:  51%|█████████▊         | 2.32G/4.51G [00:54<00:50, 43.2MB/s]
#
# model.safetensors:  52%|█████████▊         | 2.33G/4.51G [00:55<00:50, 43.0MB/s]
#
# model.safetensors:  52%|█████████▊         | 2.34G/4.51G [00:55<00:50, 42.7MB/s]
#
# model.safetensors:  52%|█████████▉         | 2.35G/4.51G [00:55<00:50, 42.4MB/s]
#
# model.safetensors:  52%|█████████▉         | 2.36G/4.51G [00:55<00:50, 42.4MB/s]
#
# model.safetensors:  53%|█████████▉         | 2.37G/4.51G [00:56<00:50, 42.1MB/s]
#
# model.safetensors:  53%|██████████         | 2.38G/4.51G [00:56<00:50, 42.4MB/s]
#
# model.safetensors:  53%|██████████         | 2.39G/4.51G [00:56<00:49, 42.6MB/s]
#
# model.safetensors:  53%|██████████         | 2.40G/4.51G [00:56<00:49, 42.3MB/s]
#
# model.safetensors:  53%|██████████▏        | 2.41G/4.51G [00:57<00:49, 42.3MB/s]
#
# model.safetensors:  54%|██████████▏        | 2.42G/4.51G [00:57<00:49, 42.3MB/s]
#
# model.safetensors:  54%|██████████▏        | 2.43G/4.51G [00:57<00:49, 42.3MB/s]
#
# model.safetensors:  54%|██████████▎        | 2.44G/4.51G [00:57<00:49, 42.2MB/s]
#
# model.safetensors:  54%|██████████▎        | 2.45G/4.51G [00:58<00:48, 42.1MB/s]
#
# model.safetensors:  55%|██████████▍        | 2.46G/4.51G [00:58<00:49, 41.8MB/s]
#
# model.safetensors:  55%|██████████▍        | 2.47G/4.51G [00:58<00:48, 42.0MB/s]
#
# model.safetensors:  55%|██████████▍        | 2.49G/4.51G [00:58<00:48, 42.1MB/s]
#
# model.safetensors:  55%|██████████▌        | 2.50G/4.51G [00:59<00:59, 33.9MB/s]
#
# model.safetensors:  56%|██████████▌        | 2.51G/4.51G [00:59<00:51, 39.2MB/s]
#
# model.safetensors:  56%|██████████▌        | 2.52G/4.51G [00:59<00:44, 45.1MB/s]
#
# model.safetensors:  56%|██████████▋        | 2.53G/4.51G [00:59<00:43, 45.4MB/s]
#
# model.safetensors:  56%|██████████▋        | 2.54G/4.51G [01:00<00:44, 44.5MB/s]
#
# model.safetensors:  56%|██████████▋        | 2.55G/4.51G [01:00<00:44, 44.1MB/s]
#
# model.safetensors:  57%|██████████▊        | 2.56G/4.51G [01:00<00:45, 43.4MB/s]
#
# model.safetensors:  57%|██████████▊        | 2.57G/4.51G [01:00<00:44, 43.2MB/s]
#
# model.safetensors:  57%|██████████▊        | 2.58G/4.51G [01:01<00:45, 42.9MB/s]
#
# model.safetensors:  57%|██████████▉        | 2.59G/4.51G [01:01<00:41, 46.0MB/s]
#
# model.safetensors:  58%|██████████▉        | 2.60G/4.51G [01:01<00:37, 50.8MB/s]
#
# model.safetensors:  58%|██████████▉        | 2.61G/4.51G [01:01<00:35, 52.9MB/s]
#
# model.safetensors:  58%|███████████        | 2.62G/4.51G [01:01<00:32, 57.3MB/s]
#
# model.safetensors:  58%|███████████        | 2.63G/4.51G [01:02<00:35, 52.5MB/s]
#
# model.safetensors:  59%|███████████▏       | 2.64G/4.51G [01:02<00:38, 48.8MB/s]
#
# model.safetensors:  59%|███████████▏       | 2.65G/4.51G [01:02<00:39, 46.5MB/s]
#
# model.safetensors:  59%|███████████▏       | 2.66G/4.51G [01:02<00:41, 45.0MB/s]
#
# model.safetensors:  59%|███████████▎       | 2.67G/4.51G [01:03<00:41, 44.1MB/s]
#
# model.safetensors:  59%|███████████▎       | 2.68G/4.51G [01:03<00:42, 42.7MB/s]
#
# model.safetensors:  60%|███████████▎       | 2.69G/4.51G [01:03<00:42, 42.6MB/s]
#
# model.safetensors:  60%|███████████▍       | 2.71G/4.51G [01:03<00:42, 42.8MB/s]
#
# model.safetensors:  60%|███████████▍       | 2.72G/4.51G [01:04<00:42, 42.4MB/s]
#
# model.safetensors:  60%|███████████▍       | 2.73G/4.51G [01:04<00:42, 42.4MB/s]
#
# model.safetensors:  61%|███████████▌       | 2.74G/4.51G [01:04<00:41, 42.6MB/s]
#
# model.safetensors:  61%|███████████▌       | 2.75G/4.51G [01:04<00:41, 42.7MB/s]
#
# model.safetensors:  61%|███████████▌       | 2.76G/4.51G [01:05<00:41, 42.3MB/s]
#
# model.safetensors:  61%|███████████▋       | 2.77G/4.51G [01:05<00:41, 42.3MB/s]
#
# model.safetensors:  62%|███████████▋       | 2.78G/4.51G [01:05<00:40, 42.3MB/s]
#
# model.safetensors:  62%|███████████▋       | 2.79G/4.51G [01:05<00:40, 42.4MB/s]
#
# model.safetensors:  62%|███████████▊       | 2.80G/4.51G [01:06<00:40, 42.2MB/s]
#
# model.safetensors:  62%|███████████▊       | 2.81G/4.51G [01:06<00:40, 42.1MB/s]
#
# model.safetensors:  63%|███████████▉       | 2.82G/4.51G [01:06<00:39, 42.4MB/s]
#
# model.safetensors:  63%|███████████▉       | 2.83G/4.51G [01:06<00:39, 42.5MB/s]
#
# model.safetensors:  63%|███████████▉       | 2.84G/4.51G [01:07<00:39, 42.1MB/s]
#
# model.safetensors:  63%|████████████       | 2.85G/4.51G [01:07<00:39, 42.1MB/s]
#
# model.safetensors:  63%|████████████       | 2.86G/4.51G [01:07<00:38, 42.3MB/s]
#
# model.safetensors:  64%|████████████       | 2.87G/4.51G [01:07<00:38, 42.1MB/s]
#
# model.safetensors:  64%|████████████▏      | 2.88G/4.51G [01:08<00:38, 42.0MB/s]
#
# model.safetensors:  64%|████████████▏      | 2.89G/4.51G [01:08<00:38, 41.9MB/s]
#
# model.safetensors:  64%|████████████▏      | 2.90G/4.51G [01:08<00:38, 42.0MB/s]
#
# model.safetensors:  65%|████████████▎      | 2.92G/4.51G [01:08<00:37, 42.0MB/s]
#
# model.safetensors:  65%|████████████▎      | 2.93G/4.51G [01:08<00:37, 42.1MB/s]
#
# model.safetensors:  65%|████████████▎      | 2.94G/4.51G [01:09<00:37, 41.9MB/s]
#
# model.safetensors:  65%|████████████▍      | 2.95G/4.51G [01:09<00:37, 42.0MB/s]
#
# model.safetensors:  66%|████████████▍      | 2.96G/4.51G [01:09<00:36, 42.1MB/s]
#
# model.safetensors:  66%|████████████▍      | 2.97G/4.51G [01:10<00:37, 40.7MB/s]
#
# model.safetensors:  66%|████████████▌      | 2.98G/4.51G [01:10<00:37, 41.3MB/s]
#
# model.safetensors:  66%|████████████▌      | 2.99G/4.51G [01:10<00:36, 41.7MB/s]
#
# model.safetensors:  66%|████████████▋      | 3.00G/4.51G [01:10<00:35, 42.0MB/s]
#
# model.safetensors:  67%|████████████▋      | 3.01G/4.51G [01:11<00:35, 42.3MB/s]
#
# model.safetensors:  67%|████████████▋      | 3.02G/4.51G [01:11<00:35, 42.3MB/s]
#
# model.safetensors:  67%|████████████▊      | 3.03G/4.51G [01:11<00:34, 42.5MB/s]
#
# model.safetensors:  67%|████████████▊      | 3.04G/4.51G [01:11<00:32, 44.6MB/s]
#
# model.safetensors:  68%|████████████▊      | 3.05G/4.51G [01:11<00:30, 47.4MB/s]
#
# model.safetensors:  68%|████████████▉      | 3.06G/4.51G [01:12<00:36, 40.1MB/s]
#
# model.safetensors:  68%|████████████▉      | 3.07G/4.51G [01:12<00:35, 40.8MB/s]
#
# model.safetensors:  68%|████████████▉      | 3.08G/4.51G [01:12<00:34, 41.3MB/s]
#
# model.safetensors:  69%|█████████████      | 3.09G/4.51G [01:13<00:34, 41.0MB/s]
#
# model.safetensors:  69%|█████████████      | 3.10G/4.51G [01:13<00:33, 41.5MB/s]
#
# model.safetensors:  69%|█████████████      | 3.11G/4.51G [01:13<00:33, 41.8MB/s]
#
# model.safetensors:  69%|█████████████▏     | 3.12G/4.51G [01:13<00:33, 41.9MB/s]
#
# model.safetensors:  69%|█████████████▏     | 3.14G/4.51G [01:13<00:32, 42.0MB/s]
#
# model.safetensors:  70%|█████████████▏     | 3.15G/4.51G [01:14<00:32, 41.7MB/s]
#
# model.safetensors:  70%|█████████████▎     | 3.16G/4.51G [01:14<00:32, 41.5MB/s]
#
# model.safetensors:  70%|█████████████▎     | 3.17G/4.51G [01:14<00:32, 41.9MB/s]
#
# model.safetensors:  70%|█████████████▍     | 3.18G/4.51G [01:15<00:32, 41.7MB/s]
#
# model.safetensors:  71%|█████████████▍     | 3.19G/4.51G [01:15<00:31, 41.8MB/s]
#
# model.safetensors:  71%|█████████████▍     | 3.20G/4.51G [01:15<00:31, 42.0MB/s]
#
# model.safetensors:  71%|█████████████▌     | 3.21G/4.51G [01:15<00:30, 42.2MB/s]
#
# model.safetensors:  71%|█████████████▌     | 3.22G/4.51G [01:15<00:30, 42.0MB/s]
#
# model.safetensors:  72%|█████████████▌     | 3.23G/4.51G [01:16<00:30, 41.9MB/s]
#
# model.safetensors:  72%|█████████████▋     | 3.24G/4.51G [01:16<00:30, 42.1MB/s]
#
# model.safetensors:  72%|█████████████▋     | 3.25G/4.51G [01:16<00:29, 42.4MB/s]
#
# model.safetensors:  72%|█████████████▋     | 3.26G/4.51G [01:16<00:29, 42.4MB/s]
#
# model.safetensors:  73%|█████████████▊     | 3.27G/4.51G [01:17<00:29, 41.6MB/s]
#
# model.safetensors:  73%|█████████████▊     | 3.28G/4.51G [01:17<00:29, 41.8MB/s]
#
# model.safetensors:  73%|█████████████▊     | 3.29G/4.51G [01:17<00:29, 41.8MB/s]
#
# model.safetensors:  73%|█████████████▉     | 3.30G/4.51G [01:17<00:28, 41.9MB/s]
#
# model.safetensors:  73%|█████████████▉     | 3.31G/4.51G [01:18<00:28, 41.8MB/s]
#
# model.safetensors:  74%|█████████████▉     | 3.32G/4.51G [01:18<00:28, 42.2MB/s]
#
# model.safetensors:  74%|██████████████     | 3.33G/4.51G [01:18<00:27, 42.1MB/s]
#
# model.safetensors:  74%|██████████████     | 3.34G/4.51G [01:18<00:27, 42.3MB/s]
#
# model.safetensors:  74%|██████████████▏    | 3.36G/4.51G [01:19<00:27, 41.7MB/s]
#
# model.safetensors:  75%|██████████████▏    | 3.37G/4.51G [01:19<00:27, 41.9MB/s]
#
# model.safetensors:  75%|██████████████▏    | 3.38G/4.51G [01:19<00:26, 42.2MB/s]
#
# model.safetensors:  75%|██████████████▎    | 3.39G/4.51G [01:19<00:26, 42.1MB/s]
#
# model.safetensors:  75%|██████████████▎    | 3.40G/4.51G [01:20<00:26, 41.6MB/s]
#
# model.safetensors:  76%|██████████████▎    | 3.41G/4.51G [01:20<00:26, 41.6MB/s]
#
# model.safetensors:  76%|██████████████▍    | 3.42G/4.51G [01:20<00:26, 42.0MB/s]
#
# model.safetensors:  76%|██████████████▍    | 3.43G/4.51G [01:20<00:25, 42.2MB/s]
#
# model.safetensors:  76%|██████████████▍    | 3.44G/4.51G [01:21<00:25, 41.7MB/s]
#
# model.safetensors:  76%|██████████████▌    | 3.45G/4.51G [01:21<00:25, 41.1MB/s]
#
# model.safetensors:  77%|██████████████▌    | 3.46G/4.51G [01:21<00:25, 41.5MB/s]
#
# model.safetensors:  77%|██████████████▌    | 3.47G/4.51G [01:22<00:25, 41.6MB/s]
#
# model.safetensors:  77%|██████████████▋    | 3.48G/4.51G [01:22<00:24, 41.9MB/s]
#
# model.safetensors:  77%|██████████████▋    | 3.49G/4.51G [01:22<00:24, 42.2MB/s]
#
# model.safetensors:  78%|██████████████▋    | 3.50G/4.51G [01:22<00:23, 42.4MB/s]
#
# model.safetensors:  78%|██████████████▊    | 3.51G/4.51G [01:23<00:29, 34.1MB/s]
#
# model.safetensors:  78%|██████████████▊    | 3.52G/4.51G [01:23<00:25, 38.1MB/s]
#
# model.safetensors:  78%|██████████████▉    | 3.53G/4.51G [01:23<00:22, 43.5MB/s]
#
# model.safetensors:  79%|██████████████▉    | 3.54G/4.51G [01:23<00:21, 45.3MB/s]
#
# model.safetensors:  79%|██████████████▉    | 3.55G/4.51G [01:24<00:21, 44.0MB/s]
#
# model.safetensors:  79%|███████████████    | 3.57G/4.51G [01:24<00:21, 43.4MB/s]
#
# model.safetensors:  79%|███████████████    | 3.58G/4.51G [01:24<00:21, 43.0MB/s]
#
# model.safetensors:  79%|███████████████    | 3.59G/4.51G [01:24<00:21, 42.9MB/s]
#
# model.safetensors:  80%|███████████████▏   | 3.60G/4.51G [01:25<00:21, 42.6MB/s]
#
# model.safetensors:  80%|███████████████▏   | 3.61G/4.51G [01:25<00:21, 42.5MB/s]
#
# model.safetensors:  80%|███████████████▏   | 3.62G/4.51G [01:25<00:21, 42.5MB/s]
#
# model.safetensors:  80%|███████████████▎   | 3.63G/4.51G [01:25<00:20, 42.1MB/s]
#
# model.safetensors:  81%|███████████████▎   | 3.64G/4.51G [01:26<00:20, 42.2MB/s]
#
# model.safetensors:  81%|███████████████▎   | 3.65G/4.51G [01:26<00:20, 42.1MB/s]
#
# model.safetensors:  81%|███████████████▍   | 3.66G/4.51G [01:26<00:20, 42.4MB/s]
#
# model.safetensors:  81%|███████████████▍   | 3.67G/4.51G [01:26<00:19, 42.5MB/s]
#
# model.safetensors:  82%|███████████████▍   | 3.68G/4.51G [01:26<00:19, 42.5MB/s]
#
# model.safetensors:  82%|███████████████▌   | 3.69G/4.51G [01:27<00:19, 42.0MB/s]
#
# model.safetensors:  82%|███████████████▌   | 3.70G/4.51G [01:27<00:19, 42.0MB/s]
#
# model.safetensors:  82%|███████████████▋   | 3.71G/4.51G [01:27<00:18, 42.1MB/s]
#
# model.safetensors:  83%|███████████████▋   | 3.72G/4.51G [01:27<00:18, 42.0MB/s]
#
# model.safetensors:  83%|███████████████▋   | 3.73G/4.51G [01:28<00:18, 41.9MB/s]
#
# model.safetensors:  83%|███████████████▊   | 3.74G/4.51G [01:28<00:18, 42.2MB/s]
#
# model.safetensors:  83%|███████████████▊   | 3.75G/4.51G [01:28<00:17, 42.2MB/s]
#
# model.safetensors:  83%|███████████████▊   | 3.76G/4.51G [01:28<00:17, 42.4MB/s]
#
# model.safetensors:  84%|███████████████▉   | 3.77G/4.51G [01:29<00:17, 41.7MB/s]
#
# model.safetensors:  84%|███████████████▉   | 3.79G/4.51G [01:29<00:17, 41.9MB/s]
#
# model.safetensors:  84%|███████████████▉   | 3.80G/4.51G [01:29<00:17, 42.0MB/s]
#
# model.safetensors:  84%|████████████████   | 3.81G/4.51G [01:29<00:16, 42.3MB/s]
#
# model.safetensors:  85%|████████████████   | 3.82G/4.51G [01:30<00:16, 41.6MB/s]
#
# model.safetensors:  85%|████████████████   | 3.83G/4.51G [01:30<00:16, 41.6MB/s]
#
# model.safetensors:  85%|████████████████▏  | 3.84G/4.51G [01:30<00:16, 41.9MB/s]
#
# model.safetensors:  85%|████████████████▏  | 3.85G/4.51G [01:30<00:15, 42.2MB/s]
#
# model.safetensors:  86%|████████████████▎  | 3.86G/4.51G [01:31<00:15, 41.8MB/s]
#
# model.safetensors:  86%|████████████████▎  | 3.87G/4.51G [01:31<00:15, 42.3MB/s]
#
# model.safetensors:  86%|████████████████▎  | 3.88G/4.51G [01:31<00:14, 42.2MB/s]
#
# model.safetensors:  86%|████████████████▍  | 3.89G/4.51G [01:31<00:14, 41.9MB/s]
#
# model.safetensors:  86%|████████████████▍  | 3.90G/4.51G [01:32<00:14, 41.7MB/s]
#
# model.safetensors:  87%|████████████████▍  | 3.91G/4.51G [01:32<00:14, 41.8MB/s]
#
# model.safetensors:  87%|████████████████▌  | 3.92G/4.51G [01:32<00:14, 42.1MB/s]
#
# model.safetensors:  87%|████████████████▌  | 3.93G/4.51G [01:33<00:14, 40.7MB/s]
#
# model.safetensors:  87%|████████████████▌  | 3.94G/4.51G [01:33<00:14, 38.8MB/s]
#
# model.safetensors:  88%|████████████████▋  | 3.95G/4.51G [01:33<00:14, 38.9MB/s]
#
# model.safetensors:  88%|████████████████▋  | 3.96G/4.51G [01:33<00:13, 41.5MB/s]
#
# model.safetensors:  88%|████████████████▋  | 3.97G/4.51G [01:34<00:12, 44.2MB/s]
#
# model.safetensors:  88%|████████████████▊  | 3.98G/4.51G [01:34<00:12, 43.7MB/s]
#
# model.safetensors:  89%|████████████████▊  | 4.00G/4.51G [01:34<00:11, 43.1MB/s]
#
# model.safetensors:  89%|████████████████▊  | 4.01G/4.51G [01:34<00:11, 42.7MB/s]
#
# model.safetensors:  89%|████████████████▉  | 4.02G/4.51G [01:34<00:11, 42.9MB/s]
#
# model.safetensors:  89%|████████████████▉  | 4.03G/4.51G [01:35<00:11, 42.3MB/s]
#
# model.safetensors:  89%|█████████████████  | 4.04G/4.51G [01:35<00:11, 42.2MB/s]
#
# model.safetensors:  90%|█████████████████  | 4.05G/4.51G [01:35<00:10, 42.3MB/s]
#
# model.safetensors:  90%|█████████████████  | 4.06G/4.51G [01:35<00:10, 42.2MB/s]
#
# model.safetensors:  90%|█████████████████▏ | 4.07G/4.51G [01:36<00:10, 41.9MB/s]
#
# model.safetensors:  90%|█████████████████▏ | 4.08G/4.51G [01:36<00:10, 42.2MB/s]
#
# model.safetensors:  91%|█████████████████▏ | 4.09G/4.51G [01:36<00:09, 42.5MB/s]
#
# model.safetensors:  91%|█████████████████▎ | 4.10G/4.51G [01:36<00:09, 42.4MB/s]
#
# model.safetensors:  91%|█████████████████▎ | 4.11G/4.51G [01:37<00:09, 41.5MB/s]
#
# model.safetensors:  91%|█████████████████▎ | 4.12G/4.51G [01:37<00:09, 41.7MB/s]
#
# model.safetensors:  92%|█████████████████▍ | 4.13G/4.51G [01:37<00:09, 42.0MB/s]
#
# model.safetensors:  92%|█████████████████▍ | 4.14G/4.51G [01:37<00:08, 42.0MB/s]
#
# model.safetensors:  92%|█████████████████▍ | 4.15G/4.51G [01:38<00:08, 41.7MB/s]
#
# model.safetensors:  92%|█████████████████▌ | 4.16G/4.51G [01:38<00:08, 41.2MB/s]
#
# model.safetensors:  93%|█████████████████▌ | 4.17G/4.51G [01:38<00:10, 33.8MB/s]
#
# model.safetensors:  93%|█████████████████▌ | 4.18G/4.51G [01:39<00:08, 38.8MB/s]
#
# model.safetensors:  93%|█████████████████▋ | 4.19G/4.51G [01:39<00:07, 42.7MB/s]
#
# model.safetensors:  93%|█████████████████▋ | 4.20G/4.51G [01:39<00:06, 45.7MB/s]
#
# model.safetensors:  93%|█████████████████▊ | 4.22G/4.51G [01:39<00:06, 44.3MB/s]
#
# model.safetensors:  94%|█████████████████▊ | 4.23G/4.51G [01:40<00:06, 43.6MB/s]
#
# model.safetensors:  94%|█████████████████▊ | 4.24G/4.51G [01:40<00:06, 41.5MB/s]
#
# model.safetensors:  94%|█████████████████▉ | 4.25G/4.51G [01:40<00:07, 35.7MB/s]
#
# model.safetensors:  94%|█████████████████▉ | 4.26G/4.51G [01:40<00:06, 37.3MB/s]
#
# model.safetensors:  95%|█████████████████▉ | 4.27G/4.51G [01:41<00:06, 38.8MB/s]
#
# model.safetensors:  95%|██████████████████ | 4.28G/4.51G [01:41<00:05, 39.9MB/s]
#
# model.safetensors:  95%|██████████████████ | 4.29G/4.51G [01:41<00:05, 40.9MB/s]
#
# model.safetensors:  95%|██████████████████ | 4.30G/4.51G [01:41<00:05, 41.4MB/s]
#
# model.safetensors:  96%|██████████████████▏| 4.31G/4.51G [01:42<00:04, 41.8MB/s]
#
# model.safetensors:  96%|██████████████████▏| 4.32G/4.51G [01:42<00:04, 41.9MB/s]
#
# model.safetensors:  96%|██████████████████▏| 4.33G/4.51G [01:42<00:04, 42.0MB/s]
#
# model.safetensors:  96%|██████████████████▎| 4.34G/4.51G [01:42<00:04, 42.1MB/s]
#
# model.safetensors:  96%|██████████████████▎| 4.35G/4.51G [01:43<00:03, 42.2MB/s]
#
# model.safetensors:  97%|██████████████████▎| 4.36G/4.51G [01:43<00:03, 42.3MB/s]
#
# model.safetensors:  97%|██████████████████▍| 4.37G/4.51G [01:43<00:03, 42.3MB/s]
#
# model.safetensors:  97%|██████████████████▍| 4.38G/4.51G [01:43<00:03, 42.2MB/s]
#
# model.safetensors:  97%|██████████████████▌| 4.39G/4.51G [01:44<00:02, 41.9MB/s]
#
# model.safetensors:  98%|██████████████████▌| 4.40G/4.51G [01:44<00:02, 41.5MB/s]
#
# model.safetensors:  98%|██████████████████▌| 4.41G/4.51G [01:44<00:02, 41.6MB/s]
#
# model.safetensors:  98%|██████████████████▋| 4.42G/4.51G [01:44<00:02, 41.8MB/s]
#
# model.safetensors:  98%|██████████████████▋| 4.44G/4.51G [01:45<00:01, 41.6MB/s]
#
# model.safetensors:  99%|██████████████████▋| 4.45G/4.51G [01:45<00:01, 42.0MB/s]
#
# model.safetensors:  99%|██████████████████▊| 4.46G/4.51G [01:45<00:01, 42.2MB/s]
#
# model.safetensors:  99%|██████████████████▊| 4.47G/4.51G [01:45<00:01, 41.6MB/s]
#
# model.safetensors:  99%|██████████████████▊| 4.48G/4.51G [01:46<00:00, 41.8MB/s]
#
# model.safetensors:  99%|██████████████████▉| 4.49G/4.51G [01:46<00:00, 42.1MB/s]
#
# model.safetensors: 100%|██████████████████▉| 4.50G/4.51G [01:46<00:00, 42.0MB/s]
#
# model.safetensors: 100%|███████████████████| 4.51G/4.51G [01:46<00:00, 42.2MB/s]
# Download complete. Moving file to /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/blobs/7049798d4a6002e3d8df810b9a31c4fe4846d35a88c7b947abe6ce5222498b16
# Fetching 9 files: 100%|███████████████████████████| 9/9 [01:47<00:00, 11.95s/it]
# /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit/snapshots/ac59869ee8c0b25c94b7cf2ed72f5814d5ed092b

# %%
# !huggingface-cli scan-cache
# Out:
# python(32639) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# REPO ID                                       REPO TYPE SIZE ON DISK NB FILES LAST_ACCESSED LAST_MODIFIED     REFS   LOCAL PATH
# --------------------------------------------- --------- ------------ -------- ------------- ----------------- ------ ---------------------------------------------------------------------------------------------
# BAAI/bge-large-en-v1.5                        model             1.3G        6 6 months ago  6 months ago      main   /Users/dushyant/.cache/huggingface/hub/models--BAAI--bge-large-en-v1.5
# BAAI/bge-reranker-large                       model            801.0        1 3 weeks ago   3 weeks ago       main   /Users/dushyant/.cache/huggingface/hub/models--BAAI--bge-reranker-large
# HuggingFaceH4/zephyr-7b-beta                  model            14.5G       16 7 months ago  7 months ago      main   /Users/dushyant/.cache/huggingface/hub/models--HuggingFaceH4--zephyr-7b-beta
# ds4sd/docling-models                          model           559.9M        9 2 months ago  2 months ago      v2.0.1 /Users/dushyant/.cache/huggingface/hub/models--ds4sd--docling-models
# meta-llama/Llama-2-7b-chat-hf                 model            614.0        1 7 months ago  7 months ago      main   /Users/dushyant/.cache/huggingface/hub/models--meta-llama--Llama-2-7b-chat-hf
# mixedbread-ai/mxbai-embed-large-v1            model           671.4M       11 3 weeks ago   3 weeks ago       main   /Users/dushyant/.cache/huggingface/hub/models--mixedbread-ai--mxbai-embed-large-v1
# mlx-community/Llama-3.2-3B-Instruct-4bit      model             1.8G        8 19 hours ago  19 hours ago      main   /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Llama-3.2-3B-Instruct-4bit
# mlx-community/Meta-Llama-3.1-8B-Instruct-4bit model             4.5G        8 2 days ago    2 days ago        main   /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Meta-Llama-3.1-8B-Instruct-4bit
# mlx-community/Ministral-8B-Instruct-2410-4bit model             4.5G        9 2 minutes ago a few seconds ago main   /Users/dushyant/.cache/huggingface/hub/models--mlx-community--Ministral-8B-Instruct-2410-4bit
# openai/clip-vit-large-patch14                 model             1.5M        5 5 months ago  5 months ago      main   /Users/dushyant/.cache/huggingface/hub/models--openai--clip-vit-large-patch14
# runwayml/stable-diffusion-v1-5                model             1.6M       11 5 months ago  5 months ago      main   /Users/dushyant/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5
# sentence-transformers/all-MiniLM-L6-v2        model            91.6M       11 3 weeks ago   6 weeks ago       main   /Users/dushyant/.cache/huggingface/hub/models--sentence-transformers--all-MiniLM-L6-v2
# stabilityai/stable-diffusion-2-1              model             1.6M       10 5 months ago  5 months ago      main   /Users/dushyant/.cache/huggingface/hub/models--stabilityai--stable-diffusion-2-1
#
# Done in 0.0s. Scanned 13 repo(s) for a total of 28.0G.
# Got 3 warning(s) while scanning. Use -vvv to print details.

# %%
# !python -m mlx_lm.fuse -h
# Out:
# python(98670) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Loading pretrained model
# usage: fuse.py [-h] [--model MODEL] [--save-path SAVE_PATH]
#                [--adapter-path ADAPTER_PATH] [--hf-path HF_PATH]
#                [--upload-repo UPLOAD_REPO] [--de-quantize] [--export-gguf]
#                [--gguf-path GGUF_PATH]
#
# Fuse fine-tuned adapters into the base model.
#
# options:
#   -h, --help            show this help message and exit
#   --model MODEL         The path to the local model directory or Hugging Face
#                         repo.
#   --save-path SAVE_PATH
#                         The path to save the fused model.
#   --adapter-path ADAPTER_PATH
#                         Path to the trained adapter weights and config.
#   --hf-path HF_PATH     Path to the original Hugging Face model. Required for
#                         upload if --model is a local directory.
#   --upload-repo UPLOAD_REPO
#                         The Hugging Face repo to upload the model to.
#   --de-quantize         Generate a de-quantized model.
#   --export-gguf         Export model weights in GGUF format.
#   --gguf-path GGUF_PATH
#                         Path to save the exported GGUF format model weights.
#                         Default is ggml-model-f16.gguf.

# %%
# !python -m mlx_lm.lora \
  --model mlx-community/Ministral-8B-Instruct-2410-4bit \
  --data data \
  --train \
  --fine-tune-type lora \
  --batch-size 4\
  --num-layers 16\
  --iters 1000 \
  --adapter-path adapters
# Out:
# Loading pretrained model
# Fetching 7 files: 100%|███████████████████████| 7/7 [00:00<00:00, 158703.39it/s]
# Loading datasets
# Training
# Trainable parameters: 0.048% (3.834M/8019.808M)
# Starting training..., iters: 1000
# Iter 1: Val loss 2.942, Val took 32.509s
# Iter 10: Train loss 2.252, Learning Rate 1.000e-05, It/sec 0.230, Tokens/sec 67.471, Trained Tokens 2939, Peak mem 8.775 GB
# Iter 20: Train loss 0.977, Learning Rate 1.000e-05, It/sec 0.269, Tokens/sec 73.742, Trained Tokens 5679, Peak mem 8.775 GB
# Iter 30: Train loss 0.811, Learning Rate 1.000e-05, It/sec 0.284, Tokens/sec 82.845, Trained Tokens 8601, Peak mem 8.775 GB
# Iter 40: Train loss 0.566, Learning Rate 1.000e-05, It/sec 0.292, Tokens/sec 77.196, Trained Tokens 11241, Peak mem 8.775 GB
# Iter 50: Train loss 0.687, Learning Rate 1.000e-05, It/sec 0.369, Tokens/sec 103.099, Trained Tokens 14038, Peak mem 8.775 GB
# Iter 60: Train loss 0.645, Learning Rate 1.000e-05, It/sec 0.391, Tokens/sec 112.198, Trained Tokens 16904, Peak mem 8.775 GB
# Iter 70: Train loss 0.691, Learning Rate 1.000e-05, It/sec 0.321, Tokens/sec 92.625, Trained Tokens 19789, Peak mem 8.775 GB
# Iter 80: Train loss 0.730, Learning Rate 1.000e-05, It/sec 0.313, Tokens/sec 91.859, Trained Tokens 22725, Peak mem 8.775 GB
# Iter 90: Train loss 0.450, Learning Rate 1.000e-05, It/sec 0.446, Tokens/sec 116.323, Trained Tokens 25336, Peak mem 8.775 GB
# Iter 100: Train loss 0.633, Learning Rate 1.000e-05, It/sec 0.396, Tokens/sec 111.949, Trained Tokens 28166, Peak mem 8.775 GB
# Iter 100: Saved adapter weights to adapters/adapters.safetensors and adapters/0000100_adapters.safetensors.
# Iter 110: Train loss 0.449, Learning Rate 1.000e-05, It/sec 0.442, Tokens/sec 117.072, Trained Tokens 30814, Peak mem 8.775 GB
# Iter 120: Train loss 0.480, Learning Rate 1.000e-05, It/sec 0.312, Tokens/sec 80.921, Trained Tokens 33406, Peak mem 8.775 GB
# Iter 130: Train loss 0.570, Learning Rate 1.000e-05, It/sec 0.281, Tokens/sec 79.700, Trained Tokens 36243, Peak mem 8.775 GB
# Iter 140: Train loss 0.610, Learning Rate 1.000e-05, It/sec 0.289, Tokens/sec 81.169, Trained Tokens 39054, Peak mem 8.775 GB
# Iter 150: Train loss 0.577, Learning Rate 1.000e-05, It/sec 0.398, Tokens/sec 112.635, Trained Tokens 41886, Peak mem 8.775 GB
# Iter 160: Train loss 0.633, Learning Rate 1.000e-05, It/sec 0.390, Tokens/sec 108.298, Trained Tokens 44663, Peak mem 8.775 GB
# Iter 170: Train loss 0.798, Learning Rate 1.000e-05, It/sec 0.360, Tokens/sec 112.607, Trained Tokens 47791, Peak mem 8.775 GB
# Iter 180: Train loss 0.761, Learning Rate 1.000e-05, It/sec 0.343, Tokens/sec 107.924, Trained Tokens 50938, Peak mem 8.775 GB
# Iter 190: Train loss 0.550, Learning Rate 1.000e-05, It/sec 0.351, Tokens/sec 99.005, Trained Tokens 53759, Peak mem 8.775 GB
# Iter 200: Val loss 0.613, Val took 33.694s
# Iter 200: Train loss 0.693, Learning Rate 1.000e-05, It/sec 4.313, Tokens/sec 1275.656, Trained Tokens 56717, Peak mem 8.775 GB
# Iter 200: Saved adapter weights to adapters/adapters.safetensors and adapters/0000200_adapters.safetensors.
# Iter 210: Train loss 0.528, Learning Rate 1.000e-05, It/sec 0.391, Tokens/sec 108.264, Trained Tokens 59488, Peak mem 8.775 GB
# Iter 220: Train loss 0.415, Learning Rate 1.000e-05, It/sec 0.437, Tokens/sec 111.856, Trained Tokens 62046, Peak mem 8.775 GB
# Iter 230: Train loss 0.639, Learning Rate 1.000e-05, It/sec 0.364, Tokens/sec 108.331, Trained Tokens 65019, Peak mem 8.775 GB
# Iter 240: Train loss 0.543, Learning Rate 1.000e-05, It/sec 0.393, Tokens/sec 107.788, Trained Tokens 67763, Peak mem 8.775 GB
# Iter 250: Train loss 0.507, Learning Rate 1.000e-05, It/sec 0.428, Tokens/sec 115.860, Trained Tokens 70471, Peak mem 8.775 GB
# Iter 260: Train loss 0.547, Learning Rate 1.000e-05, It/sec 0.357, Tokens/sec 98.926, Trained Tokens 73245, Peak mem 8.775 GB
# Iter 270: Train loss 0.503, Learning Rate 1.000e-05, It/sec 0.365, Tokens/sec 100.442, Trained Tokens 75995, Peak mem 8.775 GB
# Iter 280: Train loss 0.620, Learning Rate 1.000e-05, It/sec 0.373, Tokens/sec 106.280, Trained Tokens 78842, Peak mem 8.775 GB
# Iter 290: Train loss 0.488, Learning Rate 1.000e-05, It/sec 0.362, Tokens/sec 96.859, Trained Tokens 81518, Peak mem 8.775 GB
# Iter 300: Train loss 0.594, Learning Rate 1.000e-05, It/sec 0.391, Tokens/sec 114.124, Trained Tokens 84438, Peak mem 8.775 GB
# Iter 300: Saved adapter weights to adapters/adapters.safetensors and adapters/0000300_adapters.safetensors.
# Iter 310: Train loss 0.677, Learning Rate 1.000e-05, It/sec 0.274, Tokens/sec 80.376, Trained Tokens 87372, Peak mem 8.775 GB
# Iter 320: Train loss 0.682, Learning Rate 1.000e-05, It/sec 0.296, Tokens/sec 86.866, Trained Tokens 90305, Peak mem 8.775 GB
# Iter 330: Train loss 0.552, Learning Rate 1.000e-05, It/sec 0.279, Tokens/sec 79.100, Trained Tokens 93137, Peak mem 8.775 GB
# Iter 340: Train loss 0.564, Learning Rate 1.000e-05, It/sec 0.397, Tokens/sec 111.231, Trained Tokens 95941, Peak mem 8.775 GB
# Iter 350: Train loss 0.638, Learning Rate 1.000e-05, It/sec 0.298, Tokens/sec 87.374, Trained Tokens 98875, Peak mem 8.775 GB
# Iter 360: Train loss 0.532, Learning Rate 1.000e-05, It/sec 0.324, Tokens/sec 92.165, Trained Tokens 101722, Peak mem 8.775 GB
# Iter 370: Train loss 0.559, Learning Rate 1.000e-05, It/sec 0.345, Tokens/sec 92.914, Trained Tokens 104419, Peak mem 8.775 GB
# Iter 380: Train loss 0.460, Learning Rate 1.000e-05, It/sec 0.422, Tokens/sec 111.409, Trained Tokens 107059, Peak mem 8.775 GB
# Iter 390: Train loss 0.681, Learning Rate 1.000e-05, It/sec 0.291, Tokens/sec 88.141, Trained Tokens 110093, Peak mem 8.775 GB
# Iter 400: Val loss 0.663, Val took 47.547s
# Iter 400: Train loss 0.440, Learning Rate 1.000e-05, It/sec 3.676, Tokens/sec 958.448, Trained Tokens 112700, Peak mem 8.775 GB
# Iter 400: Saved adapter weights to adapters/adapters.safetensors and adapters/0000400_adapters.safetensors.
# Iter 410: Train loss 0.614, Learning Rate 1.000e-05, It/sec 0.365, Tokens/sec 103.190, Trained Tokens 115531, Peak mem 8.775 GB
# Iter 420: Train loss 0.749, Learning Rate 1.000e-05, It/sec 0.312, Tokens/sec 95.729, Trained Tokens 118603, Peak mem 8.775 GB
# Iter 430: Train loss 0.644, Learning Rate 1.000e-05, It/sec 0.356, Tokens/sec 107.123, Trained Tokens 121613, Peak mem 8.775 GB
# Iter 440: Train loss 0.524, Learning Rate 1.000e-05, It/sec 0.361, Tokens/sec 103.011, Trained Tokens 124465, Peak mem 8.791 GB
# Iter 450: Train loss 0.539, Learning Rate 1.000e-05, It/sec 0.365, Tokens/sec 99.503, Trained Tokens 127192, Peak mem 8.791 GB
# Iter 460: Train loss 0.658, Learning Rate 1.000e-05, It/sec 0.290, Tokens/sec 85.134, Trained Tokens 130132, Peak mem 8.791 GB
# Iter 470: Train loss 0.474, Learning Rate 1.000e-05, It/sec 0.395, Tokens/sec 106.028, Trained Tokens 132818, Peak mem 8.791 GB
# Iter 480: Train loss 0.700, Learning Rate 1.000e-05, It/sec 0.330, Tokens/sec 99.187, Trained Tokens 135827, Peak mem 8.791 GB
# Iter 490: Train loss 0.578, Learning Rate 1.000e-05, It/sec 0.317, Tokens/sec 89.857, Trained Tokens 138663, Peak mem 8.791 GB
# Iter 500: Train loss 0.573, Learning Rate 1.000e-05, It/sec 0.332, Tokens/sec 93.136, Trained Tokens 141471, Peak mem 8.791 GB
# Iter 500: Saved adapter weights to adapters/adapters.safetensors and adapters/0000500_adapters.safetensors.
# Iter 510: Train loss 0.619, Learning Rate 1.000e-05, It/sec 0.302, Tokens/sec 91.953, Trained Tokens 144516, Peak mem 8.791 GB
# Iter 520: Train loss 0.615, Learning Rate 1.000e-05, It/sec 0.308, Tokens/sec 88.106, Trained Tokens 147374, Peak mem 8.791 GB
# Iter 530: Train loss 0.634, Learning Rate 1.000e-05, It/sec 0.275, Tokens/sec 80.238, Trained Tokens 150289, Peak mem 8.791 GB
# Iter 540: Train loss 0.606, Learning Rate 1.000e-05, It/sec 0.254, Tokens/sec 74.750, Trained Tokens 153232, Peak mem 8.791 GB
# Iter 550: Train loss 0.567, Learning Rate 1.000e-05, It/sec 0.335, Tokens/sec 96.904, Trained Tokens 156127, Peak mem 8.791 GB
# Iter 560: Train loss 0.492, Learning Rate 1.000e-05, It/sec 0.331, Tokens/sec 89.719, Trained Tokens 158839, Peak mem 8.791 GB
# Iter 570: Train loss 0.651, Learning Rate 1.000e-05, It/sec 0.278, Tokens/sec 83.782, Trained Tokens 161853, Peak mem 8.791 GB
# Iter 580: Train loss 0.552, Learning Rate 1.000e-05, It/sec 0.308, Tokens/sec 87.557, Trained Tokens 164697, Peak mem 8.791 GB
# Iter 590: Train loss 0.565, Learning Rate 1.000e-05, It/sec 0.397, Tokens/sec 108.152, Trained Tokens 167422, Peak mem 8.791 GB
# Iter 600: Val loss 0.621, Val took 29.488s
# Iter 600: Train loss 0.622, Learning Rate 1.000e-05, It/sec 3.238, Tokens/sec 950.045, Trained Tokens 170356, Peak mem 8.791 GB
# Iter 600: Saved adapter weights to adapters/adapters.safetensors and adapters/0000600_adapters.safetensors.
# Iter 610: Train loss 0.563, Learning Rate 1.000e-05, It/sec 0.298, Tokens/sec 83.785, Trained Tokens 173171, Peak mem 8.791 GB
# Iter 620: Train loss 0.494, Learning Rate 1.000e-05, It/sec 0.357, Tokens/sec 99.875, Trained Tokens 175969, Peak mem 8.791 GB
# Iter 630: Train loss 0.685, Learning Rate 1.000e-05, It/sec 0.372, Tokens/sec 110.443, Trained Tokens 178935, Peak mem 8.791 GB
# Iter 640: Train loss 0.671, Learning Rate 1.000e-05, It/sec 0.362, Tokens/sec 108.748, Trained Tokens 181937, Peak mem 8.791 GB
# Iter 650: Train loss 0.464, Learning Rate 1.000e-05, It/sec 0.419, Tokens/sec 111.559, Trained Tokens 184601, Peak mem 8.791 GB
# Iter 660: Train loss 0.494, Learning Rate 1.000e-05, It/sec 0.390, Tokens/sec 106.920, Trained Tokens 187346, Peak mem 8.791 GB
# Iter 670: Train loss 0.411, Learning Rate 1.000e-05, It/sec 0.361, Tokens/sec 93.484, Trained Tokens 189939, Peak mem 8.791 GB
# Iter 680: Train loss 0.482, Learning Rate 1.000e-05, It/sec 0.328, Tokens/sec 89.348, Trained Tokens 192665, Peak mem 8.791 GB
# Iter 690: Train loss 0.415, Learning Rate 1.000e-05, It/sec 0.398, Tokens/sec 105.344, Trained Tokens 195311, Peak mem 8.791 GB
# Iter 700: Train loss 0.667, Learning Rate 1.000e-05, It/sec 0.357, Tokens/sec 107.599, Trained Tokens 198323, Peak mem 8.791 GB
# Iter 700: Saved adapter weights to adapters/adapters.safetensors and adapters/0000700_adapters.safetensors.
# Iter 710: Train loss 0.470, Learning Rate 1.000e-05, It/sec 0.399, Tokens/sec 105.216, Trained Tokens 200959, Peak mem 8.791 GB
# Iter 720: Train loss 0.477, Learning Rate 1.000e-05, It/sec 0.399, Tokens/sec 106.714, Trained Tokens 203636, Peak mem 8.791 GB
# Iter 730: Train loss 0.489, Learning Rate 1.000e-05, It/sec 0.406, Tokens/sec 111.722, Trained Tokens 206389, Peak mem 8.791 GB
# Iter 740: Train loss 0.612, Learning Rate 1.000e-05, It/sec 0.367, Tokens/sec 107.036, Trained Tokens 209307, Peak mem 8.791 GB
# Iter 750: Train loss 0.535, Learning Rate 1.000e-05, It/sec 0.299, Tokens/sec 81.974, Trained Tokens 212049, Peak mem 8.791 GB
# Iter 760: Train loss 0.484, Learning Rate 1.000e-05, It/sec 0.316, Tokens/sec 87.050, Trained Tokens 214806, Peak mem 8.791 GB
# Iter 770: Train loss 0.474, Learning Rate 1.000e-05, It/sec 0.357, Tokens/sec 94.898, Trained Tokens 217462, Peak mem 8.791 GB
# Iter 780: Train loss 0.565, Learning Rate 1.000e-05, It/sec 0.300, Tokens/sec 85.810, Trained Tokens 220319, Peak mem 8.791 GB
# Iter 790: Train loss 0.548, Learning Rate 1.000e-05, It/sec 0.310, Tokens/sec 85.940, Trained Tokens 223087, Peak mem 8.791 GB
# Iter 800: Val loss 0.543, Val took 29.539s
# Iter 800: Train loss 0.597, Learning Rate 1.000e-05, It/sec 3.387, Tokens/sec 958.455, Trained Tokens 225917, Peak mem 8.791 GB
# Iter 800: Saved adapter weights to adapters/adapters.safetensors and adapters/0000800_adapters.safetensors.
# Iter 810: Train loss 0.717, Learning Rate 1.000e-05, It/sec 0.294, Tokens/sec 91.170, Trained Tokens 229016, Peak mem 8.791 GB
# Iter 820: Train loss 0.495, Learning Rate 1.000e-05, It/sec 0.384, Tokens/sec 103.160, Trained Tokens 231699, Peak mem 8.791 GB
# Iter 830: Train loss 0.709, Learning Rate 1.000e-05, It/sec 0.341, Tokens/sec 105.080, Trained Tokens 234779, Peak mem 8.791 GB
# Iter 840: Train loss 0.628, Learning Rate 1.000e-05, It/sec 0.286, Tokens/sec 85.005, Trained Tokens 237750, Peak mem 8.791 GB
# Iter 850: Train loss 0.585, Learning Rate 1.000e-05, It/sec 0.313, Tokens/sec 85.861, Trained Tokens 240494, Peak mem 8.791 GB
# Iter 860: Train loss 0.587, Learning Rate 1.000e-05, It/sec 0.321, Tokens/sec 94.713, Trained Tokens 243443, Peak mem 8.791 GB
# Iter 870: Train loss 0.447, Learning Rate 1.000e-05, It/sec 0.411, Tokens/sec 109.817, Trained Tokens 246113, Peak mem 8.791 GB
# Iter 880: Train loss 0.674, Learning Rate 1.000e-05, It/sec 0.289, Tokens/sec 88.889, Trained Tokens 249189, Peak mem 8.791 GB
# Iter 890: Train loss 0.575, Learning Rate 1.000e-05, It/sec 0.349, Tokens/sec 97.913, Trained Tokens 251991, Peak mem 8.791 GB
# Iter 900: Train loss 0.598, Learning Rate 1.000e-05, It/sec 0.311, Tokens/sec 92.071, Trained Tokens 254951, Peak mem 8.791 GB
# Iter 900: Saved adapter weights to adapters/adapters.safetensors and adapters/0000900_adapters.safetensors.
# Iter 910: Train loss 0.568, Learning Rate 1.000e-05, It/sec 0.280, Tokens/sec 78.055, Trained Tokens 257743, Peak mem 8.791 GB
# Iter 920: Train loss 0.588, Learning Rate 1.000e-05, It/sec 0.385, Tokens/sec 113.165, Trained Tokens 260682, Peak mem 8.791 GB
# Iter 930: Train loss 0.693, Learning Rate 1.000e-05, It/sec 0.325, Tokens/sec 100.361, Trained Tokens 263774, Peak mem 8.791 GB
# Iter 940: Train loss 0.458, Learning Rate 1.000e-05, It/sec 0.430, Tokens/sec 114.326, Trained Tokens 266435, Peak mem 8.791 GB
# Iter 950: Train loss 0.543, Learning Rate 1.000e-05, It/sec 0.396, Tokens/sec 114.013, Trained Tokens 269317, Peak mem 8.791 GB
# Iter 960: Train loss 0.736, Learning Rate 1.000e-05, It/sec 0.345, Tokens/sec 106.087, Trained Tokens 272388, Peak mem 8.791 GB
# Iter 970: Train loss 0.594, Learning Rate 1.000e-05, It/sec 0.317, Tokens/sec 94.772, Trained Tokens 275377, Peak mem 8.791 GB
# Iter 980: Train loss 0.464, Learning Rate 1.000e-05, It/sec 0.367, Tokens/sec 100.234, Trained Tokens 278111, Peak mem 8.791 GB
# Iter 990: Train loss 0.523, Learning Rate 1.000e-05, It/sec 0.362, Tokens/sec 97.211, Trained Tokens 280798, Peak mem 8.791 GB
# Iter 1000: Val loss 0.652, Val took 30.628s
# Iter 1000: Train loss 0.529, Learning Rate 1.000e-05, It/sec 3.640, Tokens/sec 1038.207, Trained Tokens 283650, Peak mem 8.791 GB
# Iter 1000: Saved adapter weights to adapters/adapters.safetensors and adapters/0001000_adapters.safetensors.
# Saved final weights to adapters/adapters.safetensors.

# %%
# !ls adapters
# Out:
# 0000100_adapters.safetensors 0000500_adapters.safetensors
# 0000200_adapters.safetensors 0000600_adapters.safetensors
# 0000300_adapters.safetensors adapter_config.json
# 0000400_adapters.safetensors adapters.safetensors
# python(43440) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
# !python -m mlx_lm.lora \
  --model mlx-community/Ministral-8B-Instruct-2410-4bit \
  --adapter-path adapters \
  --data data \
  --test
# Out:
# python(47285) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Loading pretrained model
# Fetching 7 files: 100%|███████████████████████| 7/7 [00:00<00:00, 124936.71it/s]
# Loading datasets
# Testing
# Test loss 0.696, Test ppl 2.007.

# %%
# !python -m mlx_lm.generate \
    --model mlx-community/Ministral-8B-Instruct-2410-4bit \
    --max-tokens 500 \
    --prompt "Symptoms: I have been experiencing memory loss, stiffness and difficulty walking. Question: What could be the diagnosis I have?"
# Out:
# Fetching 7 files: 100%|███████████████████████| 7/7 [00:00<00:00, 109552.72it/s]
# ==========
# Prompt: <s>[INST]Symptoms: I have been experiencing memory loss, stiffness and difficulty walking. Question: What could be the diagnosis I have?[/INST]
# The symptoms you're describing—memory loss, stiffness, and difficulty walking—could be indicative of several conditions. Here are a few possibilities:
#
# 1. **Dementia**: This is a broad term that refers to a decline in cognitive function, including memory loss. It can be caused by various conditions, such as Alzheimer's disease, vascular dementia, or Lewy body dementia.
#
# 2. **Parkinson's Disease**: This is a neurological disorder that affects movement. It can cause stiffness, difficulty walking, and memory problems.
#
# 3. **Multiple Sclerosis (MS)**: This is an autoimmune disease that can affect the brain and spinal cord. It can cause a wide range of symptoms, including memory loss, stiffness, and difficulty walking.
#
# 4. **Normal Pressure Hydrocephalus (NPH)**: This is a condition where there is an excess of cerebrospinal fluid (CSF) in the brain. It can cause memory loss, difficulty walking, and stiffness.
#
# 5. **Brain Tumor**: While less common, a brain tumor can cause these symptoms.
#
# 6. **Infection or Inflammation**: Conditions like encephalitis or meningitis can cause similar symptoms.
#
# Given the severity and nature of your symptoms, it's crucial to consult with a healthcare professional for a thorough evaluation. They can perform tests and examinations to determine the cause of your symptoms and recommend appropriate treatment.
# ==========
# Prompt: 29 tokens, 155.215 tokens-per-sec
# Generation: 272 tokens, 38.735 tokens-per-sec
# Peak memory: 4.595 GB

# %%
# !python -m mlx_lm.generate \
    --model mlx-community/Ministral-8B-Instruct-2410-4bit \
    --max-tokens 500 \
    --adapter-path adapters \
    --prompt "Symptoms: I have been experiencing memory loss, stiffness and difficulty walking. Question: What could be the diagnosis I have?"
# Out:
# Fetching 7 files: 100%|████████████████████████| 7/7 [00:00<00:00, 16951.58it/s]
# ==========
# Prompt: <s>[INST]Symptoms: I have been experiencing memory loss, stiffness and difficulty walking. Question: What could be the diagnosis I have?[/INST]
# Based on the symptoms you've described, you could be diagnosed with Parkinson's disease. Memory loss, stiffness, and difficulty walking are common symptoms of this condition. However, it's important to note that symptoms can vary from person to person. If you're concerned about your health, it's best to consult with a healthcare professional for a proper diagnosis.
# ==========
# Prompt: 29 tokens, 152.080 tokens-per-sec
# Generation: 71 tokens, 33.169 tokens-per-sec
# Peak memory: 4.583 GB

# %%
# !python -m mlx_lm.fuse \
    --model mlx-community/Ministral-8B-Instruct-2410-4bit \
    --adapter-path adapters \
    --save-path model/fine-tuned_Ministral-8B
# Out:
# Loading pretrained model
# Fetching 7 files: 100%|████████████████████████| 7/7 [00:00<00:00, 37884.04it/s]

# %%
# !python -m mlx_lm.generate \
    --model model/fine-tuned_Ministral-8B \
    --max-tokens 500 \
    --prompt "Symptoms: I have been experiencing memory loss, stiffness and difficulty walking. Question: What could be the diagnosis I have?"
